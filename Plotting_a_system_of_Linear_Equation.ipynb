# %% [markdown]
# <a href="https://colab.research.google.com/github/Man-wilson/ML_Foundations/blob/main/Plotting_a_system_of_Linear_Equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve

# %%
t = np.linspace(0, 40, 1000)

# %% [markdown]
# **Distnce travelled by robber: d = 2.5t**

# %%
d_r = 2.5 * t

# %% [markdown]
# **Distance travelled by Sherrif d = 3(t-5)**

# %%
d_s = 3 * (t-5)

# %%
fig, ax = plt.subplots()
plt.title('Time taken to catch a bank roberr')
plt.xlabel('Time (in minutes)')
plt.ylabel('Distance (in KM)')
ax.set_xlim(0,40)
ax.set_ylim(0,  100)
ax.plot(t, d_r, color='violet')
ax.plot(t, d_s, color='green')
plt.axvline(x=30, color='crimson', linestyle='--')
plt.axhline(y=75, color='crimson', linestyle='--')

# %% [markdown]
# someone had design for generating energy his first design on 1st April generated 1kj/day and the second design on 1st May generated 4kj/day.
# so,
#
# **what day is it when second design has generated as much total energy as the first design?**
#
# **How much total energy have both generated by that day?**
#
# **what would the solution to 1 and 2 be if second design generated 1kj of power per day?**

# %%
time = np.linspace(0, 100, 100)

# %% [markdown]
# Fisrt design energy
# e = 1t

# %%
e = [1 * t for t in time]

# %% [markdown]
# second design for generating energy e = 4(t-30)

# %%
e2 = [4 * (t-30) for t in time]

# %% [markdown]
# **Question 1**

# %%
4*(t-30) == 1 * t
t
# Out:
# t

# %%
# # Define the symbol
# t, e = symbols('t e')

# # Define the equations
# equation1 = Eq(1 * t, e)
# equation2 = Eq(4 * (t - 30), e)

# # Since both equations are equal to e, we can set them equal to each other
# equation3 = Eq(1 * t, 4 * (t - 30))

# # Solve for t
# solution_t = solve(equation3, t)
# print(solution_t)

# %%
fig, ax = plt.subplots()
plt.title('Plot for Energy generation equations')
plt.xlabel('Days')
plt.ylabel('Energy (in Kj)')
ax.set_xlim(0, 60)
ax.set_ylim(0, 100)
ax.plot(time, e, label='e = t', c='blue')
ax.plot(time, e2, label='e = 4(t-30)', c='green')
plt.axvline(x = 40, c='crimson', linestyle='--')
plt.axhline(y = 40, c='crimson', linestyle='--')
